# %% [markdown]
# Scripts for opening Vicon ASF & AMC files, converting to pd.df & saving data

# %%
import numpy as np
import pandas as pd
import os
import sys
sys.path.append("..")
from src.data.amc_parser import parse_asf, parse_amc

# %%
asf_path = '../data/raw/01.asf'
amc_path = '../data/raw/01_01.amc'
joints = parse_asf(asf_path)
motions = parse_amc(amc_path)

# %%
a=[]
b=list(joints.keys())
MCapVal = pd.DataFrame(data=None,columns=b)
loopList = range(len(motions))

for i in loopList[1:]:
    joints['root'].set_motion(motions[i])
    for j in joints.values():
        a.append(j.coordinate)
        #print(j.name)
        #MCapVal[j.name].append(j.coordinate)
    #print(a)
    MCapVal.loc[len(MCapVal), :] = a
    a=[]

# %%
MCapVal.to_pickle('../data/processed/01.pickle')

# %%
type(j.coordinate[0])
np.array(motions[0]['root'][:3])[1]
# Out:
# 17.8693

# %%
pd.read_pickle('../data/processed/01.pickle')
# Out:
#                                     root  \
# 0     [[9.37285], [17.8666], [-17.3192]]
# 1     [[9.36924], [17.8658], [-17.3215]]
# 2      [[9.37257], [17.8597], [-17.326]]
# 3     [[9.37326], [17.8536], [-17.3317]]
# 4       [[9.36894], [17.853], [-17.335]]
# 5     [[9.36763], [17.8526], [-17.3375]]
# 6     [[9.36475], [17.8499], [-17.3463]]
# 7     [[9.35985], [17.8506], [-17.3603]]
# 8     [[9.35943], [17.8548], [-17.3683]]
# 9      [[9.36099], [17.855], [-17.3711]]
# 10    [[9.36491], [17.8511], [-17.3802]]
# 11     [[9.36861], [17.847], [-17.3957]]
# 12    [[9.36501], [17.8439], [-17.4052]]
# 13     [[9.35818], [17.841], [-17.4103]]
# 14    [[9.35686], [17.8409], [-17.4189]]
# 15      [[9.36285], [17.8425], [-17.43]]
# 16    [[9.36661], [17.8451], [-17.4445]]
# 17     [[9.36703], [17.8486], [-17.458]]
# 18    [[9.36956], [17.8509], [-17.4719]]
# 19    [[9.37563], [17.8545], [-17.4876]]
# 20     [[9.3804], [17.8569], [-17.5011]]
# 21     [[9.37864], [17.857], [-17.5139]]
# ...

# %%
MCapVal
# Out:
#                                     root  \
# 0     [[9.37285], [17.8666], [-17.3192]]
# 1     [[9.36924], [17.8658], [-17.3215]]
# 2      [[9.37257], [17.8597], [-17.326]]
# 3     [[9.37326], [17.8536], [-17.3317]]
# 4       [[9.36894], [17.853], [-17.335]]
# 5     [[9.36763], [17.8526], [-17.3375]]
# 6     [[9.36475], [17.8499], [-17.3463]]
# 7     [[9.35985], [17.8506], [-17.3603]]
# 8     [[9.35943], [17.8548], [-17.3683]]
# 9      [[9.36099], [17.855], [-17.3711]]
# 10    [[9.36491], [17.8511], [-17.3802]]
# 11     [[9.36861], [17.847], [-17.3957]]
# 12    [[9.36501], [17.8439], [-17.4052]]
# 13     [[9.35818], [17.841], [-17.4103]]
# 14    [[9.35686], [17.8409], [-17.4189]]
# 15      [[9.36285], [17.8425], [-17.43]]
# 16    [[9.36661], [17.8451], [-17.4445]]
# 17     [[9.36703], [17.8486], [-17.458]]
# 18    [[9.36956], [17.8509], [-17.4719]]
# 19    [[9.37563], [17.8545], [-17.4876]]
# 20     [[9.3804], [17.8569], [-17.5011]]
# 21     [[9.37864], [17.857], [-17.5139]]
# ...
